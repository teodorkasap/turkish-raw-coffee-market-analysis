# %%
import pandas as pd
import numpy as np

# %%
file1 = '2000-2019-ithalat-ihracat-rakamlari.xls'
table1 = pd.read_excel(file1, skiprows=list(range(1)))
table1
# Out:
#     year         hs12                             description unit  export  \
# 0   2000  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   1.014
# 1   2001  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   7.448
# 2   2002  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t  15.897
# 3   2003  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t  23.612
# 4   2004  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   9.936
# 5   2005  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   7.105
# 6   2006  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   4.037
# 7   2007  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t  10.154
# 8   2008  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   9.086
# 9   2009  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   6.137
# 10  2010  90111000000  Kahve (kafeini alınmamış, kavrulmamış)    t   4.469
# ...
